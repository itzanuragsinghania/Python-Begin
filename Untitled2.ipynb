# %%
i=input(" Enter ur Name")
if i<5:
    print("PLZ Enter name more than 5 charecter")
else:
    print("i")
# Out:
#  Enter ur Namehh
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-a88e08aff97b> in <module>
#       1 i=input(" Enter ur Name").format(5,20)
# ----> 2 if i<5:
#       3     print("PLZ Enter name more than 5 charecter")
#       4 else:
#       5     print("i")
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
from tkinter import *
